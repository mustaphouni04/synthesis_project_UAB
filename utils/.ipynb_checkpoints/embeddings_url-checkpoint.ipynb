# %%
import pandas as pd
# load data
df = pd.read_csv("../data/combined_logs.csv")

df['requested_url'].head()
# Out:
# 0    /fr/pag492/explora-platges-i-ports-2/id12/les-...
# 1    /fr/pag492/explora-platges-i-ports-2/id12/les-...
# 2    /ca/noticias/84/sitges-obt%C3%A9-el-certificat...
# 3    /fr/pag492/explora-platges-i-ports-2/id12/les-...
# 4    /fr/pag492/explora-platges-i-ports-2/id12/les-...
# Name: requested_url, dtype: object

# %% [markdown]
# ## Importing necessary libraries

# %%
import nltk
import re
import sqlite3
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from string import punctuation
from keras.preprocessing import text
from urllib.parse import unquote
from nltk.tokenize import word_tokenize
from nltk.corpus import PlaintextCorpusReader
from gensim.models import Word2Vec
import multiprocessing
physical_devices = tf.config.list_physical_devices('GPU')
# physical_devices

# "../example.csv"

# %% [markdown]
# ## Creating the corpus of words

# %%
def preprocess_url(url):
    url = re.sub(r'[/.-]', ' ', url)
    tokens = word_tokenize(url)
    return tokens

# load data
conn = sqlite3.connect('data.db')
df.to_sql('data', conn, index=False, if_exists='replace')

# tokenize URLs and create corpus
corpus_path = "corpus"
url_tokens = []

chunk_size = 10000
for chunk in pd.read_sql_query('SELECT requested_url FROM data', conn, chunksize=chunk_size):
    urls = chunk['requested_url']
    for url in urls:
        decoded_url = unquote(url)
        tokens = preprocess_url(decoded_url)
        url_tokens.append(tokens)

conn.close()

# save corpus to file
corpus_raw = '\n'.join([' '.join(tokens) for tokens in url_tokens])
with open(corpus_path + "/url_corpus_preprocessed.txt", "w", encoding="utf-8") as f:
    f.write(corpus_raw)

print("Corpus created successfully.")
# Out:
# Corpus created successfully.

# %%
print(url_tokens[:3])
# Out:
# [['fr', 'pag492', 'explora', 'platges', 'i', 'ports', '2', 'id12', 'les', 'anquines', 'htm'], ['fr', 'pag492', 'explora', 'platges', 'i', 'ports', '2', 'id12', 'les', 'anquines', 'htm'], ['ca', 'noticias', '84', 'sitges', 'obté', 'el', 'certificat', 'de', 'turisme', 'responsable', 'biosphere', 'html']]

# %%
EMB_DIM = 30

w2v = Word2Vec(sentences=url_tokens, vector_size=EMB_DIM, window=5, min_count=5, negative=15,
               epochs=10, workers=multiprocessing.cpu_count())

# %%
word_vectors = w2v.wv
result = word_vectors.similar_by_word("ports")
print("Most similar to 'ports':\n", result[:3])

result = word_vectors.similar_by_word("aguila")
print("Most similar to 'aguila':\n", result[:3])

result = word_vectors.similar_by_word("images")
print("Most similar to 'images':\n", result[:3])
# Out:
# Most similar to 'ports':
#  [('id583', 0.7638565897941589), ('id577', 0.7553904056549072), ('certificades', 0.7302131652832031)]
# Most similar to 'aguila':
#  [('cuabarrada', 0.906804084777832), ('id1096', 0.6931478381156921), ('descobreix', 0.6790328025817871)]
# Most similar to 'images':
#  [('imgs', 0.5467956066131592), ('aiguadol', 0.5330745577812195), ('vista', 0.5267533659934998)]

# %%
# get the vocabulary
vocab = list(word_vectors.key_to_index.keys())
print(vocab)
# get the word vectors
word_vecs = [word_vectors[word] for word in vocab]
# convert word_vecs to a numpy array
word_vecs_np = np.array(word_vecs)
#print(word_vecs_np[4])
# Out:
# ['js', 'css', 'turisme', 'plantilles', '?', 'comu', 'jquery', 'fancybox', 'estils', 'de', 'htm', 'media', 'sitges', '0', 'site1', 'min', 'images', 'cache', 'helpers', 'v=1', 'img', 'png', 'v=3', 'jpg', '1', 'redim', 'html', 'php', 'eltemps', 'noticias', '7', 'flowplayer', 'ca', 'la', 'font', 'logo', 'blog', 'el', 'en', 'ui', '5', 'menu', '&', '6', 'svg', 'skin', 'screen', 'mw800', 'buttons', 'thumbs', 'v=5', 'woff2', 'Black', 'Intro', 'es', 'lib', 'ico', 'a', 'cookies', '3', 'wstemps', 'site=1', 'gif', 'pl409', 'enc', 'fr', 'form', 'x2', 'prop', '13', '31', '2', 'del', 'temps3', 'base', 'old', 'calendari', 'favicon', 'accions', 'v=11', 'v=23', 'mw500', 'v=14', 'print', 'browser', 'animate', 'oncssanimationend', 'v=16', 'capcalera', 'mw900', 'v=2', 'v=8', 'cookiemanager', 'minified', 'hoverIntent', 'v=6', 'responsivemenu', 'v=7', 'mw1200', 'woff', 'Brushways', 'Alt', 'Caps', 'pl330', 'w480', 'h480', 'i', 'nl', 'pkgd', 'imagesloaded', 'masonry', 'pl30', 'que', 'pl415', 'FormChek', 'imgs', 'viatge', 'planifica', 'teu', 'llistat', 'agenda', 'per', 'maps', 'plan', 'h500', 'w445', 'h238', 'peu', 'pl349', 'pictogramestaules', 'amb', 'select2', 'search', 'les', 'bgvideo', 'video', 'bg', 'd', 'carnaval', 'txt', 'barcelona', 'robots', 'al', 'festival', 'seccion', 'arrow', 'mant', 'of', 'actualidad', 'un', 'mapa', 'jpeg', 'news', 'sie', 'l=cat', 'top', 'actualitat', 'w171', 'votre', 'planifiez', 'voyage', 'pl50', 'l', 'garraf', 'ihre', 'reise', 'planen', 'met', 'des', 'explora', 'icon', 'internacional', 'lang=en', 'una', 'biosphere', 'your', 'lang=es', 'pinterest', 'trip', 'instagram', 'facebook', 'twitter', 'youtube', 'els', 'je', 'maricel', 'reis', 'b', 'lang=ca', 'ajuntament', 'in', 'blanco', 'pl7', 'auf', 'to', 'calendar', 'cat', 'festa', 'costa', 'services', 'carte', 'the', 'einen', 'cultura64', 'y', 'gold', 'blick', 'marineres', 'viles', 'dti', 'pagespeed', 'lang=fr', 'presenta', 'wp', 'platges', 'port', 'kalender', 'festa64', 'cavalls', 'fer', 'down', 'ic', 'setmana', 'prop50', 'interes', 'cartell', '2024', 'cat_409=445', 'icone', 'l=es', 'l=en', 'parc', 'big', 'w400', 'l=fr', 'up', 'map', 'l=al', 'aktuelles', 'site', 'actualites', 'l=it', 'malvasia', 'touch', 'para', 'webmanifest', 'terramar', 'cultural', 'kaart', 'diensten', '2023', 'facilities', 'servicios', 'serveis', 'dels', 'cat_409=450', 'ruta', 'do', 'lang=de', 'explore', 'mort', 'what', 'tapa', 'las', 'h=40', 'w=40', 'home', 'mes', 'pl355', 'nieuws', '2004', 'platja', 'ports', 'con', 'exposicio', 'palau', 'museu', 'fira', 'interest', 'w492', 'los', 'santa', 'montserrat', 'teatre', 'fitur', 'h354', 'arriba', 'dy0', 'aiguadolc', '4', 'id3', 'playa', 'dx0', 'centre', 'carretera', 'carnaval24', 'se', 'hacer', 'patchwork', 'com', 'market', 'carrer', 'noticies', 'faire', 'pl5', 'cau', 'globe', 'corpus', 'lliures', 'cat_409=441', 'celebra', 'h550', 'torna', 'beach', 'pregonera', 'blogs', 'lijst', '190621', 'programa', 'sant', 'data', 'cursa', 'llits', 'erleben', 'mercat', 'turismo', 'best', 'explorez', 'route', 'edicio', 'pl96', 'aquest', 'theme', 'dormir', 'ferrat', 'museus', 'apple', 'més', 'le', 'pel', 'art', 'dates', 'iban', 'nou', 'mask', '2015', 'entdecken', 'antic', 'and', 'jordi', 'comença', 'presentacio', 'urban', 'major', 'xapple', 'Ckbb8DNKrz', 'shopping', '10', 'scrap', 'pla', 'primer', 'sketchers69', 'pg=2', 'festivals', 'mar', 'obteVideo', 'vid=3', 'cat_415=443', 'id21', 'sitgestiu', 'id11', 'du', 'poesia', 'w580', 'dji', 'h320', 'place', 'die', 'te', 'ribera', 'vila', 'primera', 'cotxes', 'por', '12', 'id49', 'wtm', 'id=8', 'show_foto', 'h=34', 'w=20', 'w=27', 'h=27', 'llocs', 'miranda', 'pictogrames', 'musica', 'wat', 'doen', 'playas', 'places', 'h340', 'tourism', 'van', '_', 'w680', 'seu', 'jardins', 'id94', 'pag492', 'id43', 'golf', '0090', '000', 'propostes', 'id22', '0077', 'content', 'beaches', 'dÈpoca', 'mgl6699', 'gay', '0158', '9357', 'mgl5268', 'verema', 'artista2', 'mgl1172', 'id97', 'bears', 'lugares', 'cal_dades_dies', 'persones', 'includes', 'activit ...

# %%
# use t-SNE to reduce dimensionality to 2D
tsne = TSNE(n_components=2, random_state=42)
word_vecs_2d = tsne.fit_transform(word_vecs_np)

# plot
plt.figure(figsize=(10, 8))
plt.scatter(word_vecs_2d[:, 0], word_vecs_2d[:, 1], alpha=0.5)

# annotate points with words
for word, (x, y) in zip(vocab, word_vecs_2d):
    plt.annotate(word, (x, y), size=3)

plt.title('t-SNE Visualization of Word Embeddings')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.grid(True)
plt.show()
# Out:
# D:\musta\envs\tensorflowV4\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 148 (\x94) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\musta\envs\tensorflowV4\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 145 (\x91) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\musta\envs\tensorflowV4\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 147 (\x93) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\musta\envs\tensorflowV4\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\musta\envs\tensorflowV4\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\musta\envs\tensorflowV4\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 149 (\x95) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\musta\envs\tensorflowV4\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 156 (\x9c) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\musta\envs\tensorflowV4\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 132 (\x84) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Function to generate nested list representation for each observation
def generate_embedding_vectors(url_tokens, word_vectors, emb_dim):
    embedding_vectors = []
    for token in url_tokens:
        if token in word_vectors:
            embedding_vectors.append(word_vectors[token])
        else:
            embedding_vectors.append([0.0] * emb_dim)  # If token not found, fill with zeros
    return embedding_vectors

# Create a new list to hold the embedding vectors
embedding_vectors_list = []

# Iterate over each observation in the dataframe
for i, row in df.iterrows():
    url = row['requested_url']
    decoded_url = unquote(url)
    tokens = preprocess_url(decoded_url)
    embedding_vectors = generate_embedding_vectors(tokens, word_vectors, EMB_DIM)
    embedding_vectors_list.append(embedding_vectors)

# Add the list of embedding vectors as a new column to the dataframe
df['embedding_vectors_url'] = embedding_vectors_list

# Display updated dataframe
print(df.head(50))
# Out:
#               server_name     remote_host remote_logname remote_user  \
# 0       sitgesanytime.com     47.76.35.19              -           -
# 1   www.sitgesanytime.com     47.76.35.19              -           -
# 2   www.sitgesanytime.com    40.77.167.53              -           -
# 3       sitgesanytime.com     47.76.35.19              -           -
# 4   www.sitgesanytime.com     47.76.35.19              -           -
# 5       sitgesanytime.com     47.76.35.19              -           -
# 6   www.sitgesanytime.com     47.76.35.19              -           -
# 7       sitgesanytime.com     47.76.35.19              -           -
# 8   www.sitgesanytime.com     47.76.35.19              -           -
# 9       sitgesanytime.com     47.76.35.19              -           -
# 10  www.sitgesanytime.com     47.76.35.19              -           -
# 11      sitgesanytime.com     47.76.35.19              -           -
# 12  www.sitgesanytime.com     47.76.35.19              -           -
# 13      sitgesanytime.com     47.76.35.19              -           -
# 14  www.sitgesanytime.com     47.76.35.19              -           -
# 15      sitgesanytime.com     47.76.35.19              -           -
# 16  www.sitgesanytime.com     47.76.35.19              -           -
# 17      sitgesanytime.com     47.76.35.19              -           -
# 18  www.sitgesanytime.com     47.76.35.19              -           -
# 19  www.sitgesanytime.com   89.247.174.98              -           -
# 20      sitgesanytime.com     47.76.35.19              -           -
# 21  www.sitgesanytime.com     47.76.35.19              -           -
# 22      sitgesanytime.com     47.76.35.19              -           -
# 23  www.sitgesanytime.com  195.82.120.225              -           -
# 24  www.sitgesanytime.com     47.76.35.19              -           -
# 25  www.sitgesanytime.com  195.82.120.225              -           -
# 26  www.sitgesanytime.com  195.82.120.225              -           -
# 27  www.sitgesanytime.com  195.82.120.225              -           -
# 28      sitgesanytime.com     47.76.35.19              -           -
# 29  www.sitgesanytime.com     47.76.35.19              -           -
# 30      sitgesanytime.com     47.76.35.19              -           -
# 31  www.sitgesanytime.com     47.76.35.19              -           -
# 32      sitgesanytime.com     47.76.35.19              -           -
# 33  www.sitgesanytime.com     47.76.35.19              -           -
# 34      sitgesanytime.com     47.76.35.19              -           -
# 35  www.sitgesanytime.com     47.76.35.19              -           -
# 36      sitgesanytime.com     47.76.35.19              -           -
# 37  www.sitgesanytime.com     47.76.35.19              -           -
# 38      sitgesanytime.com     47.76.35.19              -           -
# 39  www.sitgesanytime.com     47.76.35.19              -           -
# 40  www.sitgesanytime.com  195.82.120.225              -           -
# 41      sitgesanytime.com     47.76.35.19              -           -
# 42  www.sitgesanytime.com  195.82.120.225              -           -
# 43  www.sitgesanytime.com  195.82.120.225              -           -
# 44  www.sitgesanytime.com  195.82.120.225              -           -
# 45  www.sitgesanytime.com  195.82.120.225              -           -
# 46  www.sitgesanytime.com     47.76.35.19              -           -
# 47      sitgesanytime.com     47.76.35.19              -           -
# 48  www.sitgesanytime.com     47.76.35.19              -           -
# 49      sitgesanytime.com     47.76.35.19              -           -
#
#                      timestamp request_method  \
# 0   22/Jan/2024:00:00:00 +0100           HEAD
# 1   22/Jan/2024:00:00:01 +0100           HEAD
# 2   22/Jan/2024:00:00:06 +0100            GET
# 3   22/Jan/2024:00:00:06 +0100           HEAD
# 4   22/Jan/2024:00:00:07 +0100           HEAD
# 5   22/Jan/2024:00:00:08 +0100            GET
# 6   22/Jan/2024:00:00:08 +0100            GET
# 7   22/Jan/2024:00:00:12 +0100           HEAD
# 8   22/Jan/2024:00:00:13 +0100           HEAD
# 9   22/Jan/2024:00:00:13 +0100            GET
# 10  22/Jan/2024:00:00:14 +0100            GET
# 11  22/Jan/2024:00:00:18 +0100           HEAD
# 12  22/Jan/2024:00:00:19 +0100           HEAD
# 13  22/Jan/2024:00:00:19 +0100            GET
# 14  22/Jan/2024:00:00:20 +0100            GET
# 15  22/Jan/2024:00:00:24 +0100           HEAD
# 16  22/Jan/2024:00:00:25 +0100           HEAD
# 17  22/Jan/2024:00:00:26 +0100            GET
# 18  22/Jan/2024:00:00:26 +0100            GET
# 19  22/Jan/2024:00:00:29 +0100            GET
# 20  22/Jan/2024:00:00:30 +0100           HEAD
# 21  22/Jan/2024:00:00:31 +0100           HEAD
# 22  22/Jan/2024:00:00:32 +0100            GET
# 23  22/Jan/2024:00:00:32 +0100            GET
# 24  22/Jan/2024:00:00:32 +0100            GET
# 25  22/Jan/2024:00:00:33 +0100            GET
# 26  22/Jan/2024:00:00:33 +0100           POST
# 27  22/Jan/2024:00:00:33 +0100            GET
# 28  22/Jan/2024:00:00:36 +0100           HEAD
# 29  22/Jan/2024:00:00:37 +0100           HEAD
# 30  22/Jan/2024:00:00:37 +0100            GET
# 31  22/Jan/2024:00:00:38 +0100            GET
# 32  22/Jan/2024:00:00:42 +0100           HEAD
# 33  22/Jan/2024:00:00:43 +0100           HEAD
# 34  22/Jan/2024:00:00:44 +0100            GET
# 35  22/Jan/2024:00:00:44 +0100            GET
# 36  22/Jan/2024:00:00:48 +0100           HEAD
# 37  22/Jan/2024:00:00:49 +0100           HEAD
# 38  22/Jan/2024:00:00:49 +0100            GET
# 39  22/Jan/2024:00:00:50 +0100            GET
# 40  22/Jan/2024:00:00:54 +0100            GET
# 41  22/Jan/2024:00:00:54 +0100           HEAD
# 42  22/Jan/2024:00:00:54 +0100            GET
# 43  22/Jan/2024:00:00:54 +0100            GET
# 44  22/Jan/2024:00:00:54 +0100            GET
# 45  22/Jan/2024:00:00:54 +0100            GET
# 46  22/Jan/2024:00:00:55 +0100           HEAD
# 47  22/Jan/2024:00:00:56 +0100            GET
# 48  22/Jan/2024:00:00:56 +0100            GET
# 49  22/Jan/2024:00:01:00 +0100           HEAD
#
#                                         requested_url  status_code  \
# 0   /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 1   /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 2   /ca/noticias/84/sitges-obt%C3%A9-el-certificat...          404
# 3   /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 4   /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 5   /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 6   /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 7   /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 8   /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 9   /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 10  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 11  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 12  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 13  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 14  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 15  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 16  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 17  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 18  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 19  /media/site1/cache/images/dji-0077-2-redim-enc...          200
# 20  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 21  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 22  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 23                          /es/actualidad/agenda.htm          200
# 24  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 25  /media/site1/cache/images/aguila-cuabarrada-ga...          200
# 26                                  /comu/cookies.php          200
# 27  /plantilles/turisme/eltemps/wstemps.php?site=1...          200
# 28  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 29  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 30  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 31  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 32  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 33  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 34  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 35  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 36  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 37  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 38  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 39  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 40      /plantilles/turisme/img/ajuntament-sitges.gif          200
# 41  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 42    /plantilles/turisme/img/logo-biosphere-gold.png          200
# 43               /plantilles/turisme/img/logo-dti.png          200
# 44  /plantilles/turisme/img/logo-cat-viles-mariner...          200
# 45  /plantilles/turisme/img/logo-peu-costa-barcelo...          200
# 46  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 47  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
# 48  /fr/pag492/explora-platges-i-ports-2/id12/les-...          200
# 49  /fr/pag492/explora-platges-i-ports-2/id12/les-...          301
#
#     bytes_sent                                            referer  \
# 0         4840                                                  -
# 1         5223                                                  -
# 2         2509                                                  -
# 3         4840                                                  -
# 4         5260                                                  -
# 5          661                                                  -
# 6        10196                                                  -
# 7         4840                                                  -
# 8         5260                                                  -
# 9          661                                                  -
# 10       10196                                                  -
# 11        4840                                                  -
# 12        5260                                                  -
# 13         661                                                  -
# 14       10196                                                  -
# 15        4840                                                  -
# 16        5260                                                  -
# 17         661                                                  -
# 18       10196                                                  -
# 19      227390                            https://www.google.com/
# 20        4840                                                  -
# 21        5260                                                  -
# 22         661                                                  -
# 23       11515                                                  -
# 24       10196                                                  -
# 25       34902  https://www.sitgesanytime.com/es/actualidad/ag...
# 26         278  https://www.sitgesanytime.com/es/actualidad/ag...
# 27         454  https://www.sitgesanytime.com/es/actualidad/ag...
# 28        4840                                                  -
# 29        5260                                                  -
# 30         661                                                  -
# 31       10196                                                  -
# 32        4840                                                  -
# 33        5260                                                  -
# 34         661                                                  -
# 35       10196                                                  -
# 36        4840                                                  -
# 37        5260                                                  -
# 38         661                                                  -
# 39       10196                                                  -
# 40        5492  https://www.sitgesanytime.com/es/actualidad/ag...
# 41        4840                                                  -
# 42       25387  https://www.sitgesanytime.com/es/actualidad/ag...
# 43       15171  https://www.sitgesanytime.com/es/actualidad/ag...
# 44        9291  https://www.sitgesanytime.com/es/actualidad/ag...
# 45       56837  https://www.sitgesanytime.com/es/actualidad/ag...
# 46        5260                                                  -
# 47         661                                                  -
# 48       10196                                                  -
# 49        4840                                                  -
#
#                                            user_agent  \
# 0   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 2   Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Ge...
# 3   Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 4   Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 5   Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 6   Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 7   Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 8   Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 9   Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 10  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 11  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 12  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 13  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 14  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 15  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 16  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 17  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 18  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 19  Mozilla/5.0 (Linux; Android 12; SM-G973F Build...
# 20  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 21  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 22  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 23  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 24  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 25  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 26  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 27  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 28  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 29  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 30  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 31  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 32  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 33  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 34  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 35  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 36  Mozilla/5.0 (Windows NT 6.2; Win64; x64) Apple...
# 37  Mozilla/5.0 (Windows NT 6.2; Win64; x64) Apple...
# 38  Mozilla/5.0 (Windows NT 6.2; Win64; x64) Apple...
# 39  Mozilla/5.0 (Windows NT 6.2; Win64; x64) Apple...
# 40  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 41  Mozilla/5.0 (Windows NT 6.0; Win64; x64) Apple...
# 42  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 43  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 44  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 45  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 46  Mozilla/5.0 (Windows NT 6.0; Win64; x64) Apple...
# 47  Mozilla/5.0 (Windows NT 6.0; Win64; x64) Apple...
# 48  Mozilla/5.0 (Windows NT 6.0; Win64; x64) Apple...
# 49  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
#
#                                 embedding_vectors_url
# 0   [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 1   [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 2   [[-4.9559016, 1.8720425, 5.698968, -8.874749, ...
# 3   [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 4   [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 5   [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 6   [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 7   [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 8   [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 9   [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 10  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 11  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 12  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 13  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 14  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 15  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 16  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 17  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 18  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 19  [[11.291848, -5.734507, 4.1374836, 2.0023048, ...
# 20  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 21  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 22  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 23  [[-8.681666, 3.6611247, 4.147554, -10.28228, 3...
# 24  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 25  [[11.291848, -5.734507, 4.1374836, 2.0023048, ...
# 26  [[-5.8605795, -5.1993814, 4.548679, -0.2669335...
# 27  [[-12.768263, 0.103234105, -7.545823, 7.050202...
# 28  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 29  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 30  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 31  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 32  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 33  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 34  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 35  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 36  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 37  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 38  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 39  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 40  [[-12.768263, 0.103234105, -7.545823, 7.050202...
# 41  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 42  [[-12.768263, 0.103234105, -7.545823, 7.050202...
# 43  [[-12.768263, 0.103234105, -7.545823, 7.050202...
# 44  [[-12.768263, 0.103234105, -7.545823, 7.050202...
# 45  [[-12.768263, 0.103234105, -7.545823, 7.050202...
# 46  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 47  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 48  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
# 49  [[-12.827252, 6.384664, 1.7472954, -12.288255,...
